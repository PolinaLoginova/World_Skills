# %% [markdown]
# Я обработала таблицу, разделив сугубо по запятым. По итогу получила new_data

# %% [markdown]
# Процесс обработки датасета здесь: https://colab.research.google.com/drive/1PzEVglusI7BjoLgjytLasBptOH2h0EfH#scrollTo=K8x7uv8_ZhEf
# ![Снимок экрана от 2021-03-10 18-08-50.png](data:image/png;base64,...)

# %% [markdown]
# Полученный датасет имел следующий вид:![Снимок экрана от 2021-03-10 17-25-30.png](data:image/png;base64,...)

# %% [markdown]
# Тут видно, что полученных столбцов больше, чем было в исходном датасете. Это произошло из-за того, что я разделяла по всем запятым, не учитывая, что у меня запятых больше, чем столбцов исходного датафрейма.

# %% [markdown]
# Полученные данные я в частичном размере загрузила в файл эксель. Там я объединила 21, 22 колонки, а также 23, 24, поскольку сюда по названию столбцов оригинального датасета, а также по моим личным рассуждениям (так как других подходящих кандидатов нет), они являются цельными значениями даббл и  в данном случае запятая является не делителем между значениями, а элементом числа
# ![Снимок экрана от 2021-03-10 17-36-16.png](data:image/png;base64,...)
